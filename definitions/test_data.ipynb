# %%
import pyku

# %%
pyku.resources.get_test_data('radolan')

# %%
pyku.resources.get_test_data('cftime_data')

# %%
pyku.resources.get_test_data('hyras')

# %%
pyku.resources.get_test_data('hyras_tas')

# %%
pyku.resources.get_test_data('hyras_pr')

# %%
pyku.resources.get_test_data('hyras-monthly')

# %%
pyku.resources.get_test_data('monthly_eurocordex')

# %%
pyku.resources.get_test_data('air_temperature')

# %%
pyku.resources.get_test_data('cftime_data')

# %%
pyku.resources.get_test_data('fake_cmip6')

# %%
pyku.resources.get_test_data('GCM_CanESM5')

# %%
pyku.resources.get_test_data('MPI_ESM1_2_HR_tas')

# %%
pyku.resources.get_test_data('MPI_ESM1_2_HR_pr')

# %%
pyku.resources.get_test_data('tas_hurs')

# %%
pyku.resources.get_test_data('tas_ps_huss')

# %%
pyku.resources.get_test_data('ps_tdew')

# %%
pyku.resources.get_test_data('icon_grid_file')

# %%
pyku.resources.get_test_data('icon_grib_files')

# %% [markdown]
# ## Generation

# %%
pyku.resources.generate_fake_cmip6_data()

# %%
pyku.resources.generate_fake_datasets_with_datetimes_on_disk('/kp/scratch/shaussle/tmp')
