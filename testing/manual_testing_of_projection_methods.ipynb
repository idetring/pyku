# %% [markdown]
# # Testing of all projection methods
#
# This notebook tests all projection methods in pyku, in particular all the esmf methods. Note however that this notebook/code is not part of the test pipeline because esmf needs to be compiled, and this is not automated in the current pyku pipeline.

# %%
import pyku
import pyku.geo as geo
import pyku.meta as meta
import importlib

# %%
import importlib
import pyku

ds = pyku.resources.get_test_data('fake_cmip6_data').isel(time=0)
ds = (
    ds
    .pyku.wrap_longitudes()
    .pyku.sort_georeferencing()
    .pyku.reorder_dimensions_and_coordinates()
)

# %%
ds.pyku.project('HYR-LAEA-5').ana.one_map(var='tas')

# %%
importlib.reload(geo)
geo.project(ds, area_def='HYR-LAEA-5')

# %%
ds = ds.pyku.wrap_longitudes().pyku.sort_georeferencing()
ds = ds.compute()

# %%
projected = geo.project(ds, area_def='HYR-LAEA-5')
projected.compute().ana.one_map(var='tas')

# %%
projected = geo.project(ds, area_def='HYR-LAEA-5', method='nearest_neighbor')
projected.compute().ana.one_map(var='tas')

# %%
projected = geo.project(ds, area_def='HYR-LAEA-5', method='bilinear')
projected.compute().ana.one_map(var='tas')

# %%
projected = geo.project(ds, area_def='HYR-LAEA-5', method='idw', power_parameter=2)
projected.compute().ana.one_map(var='tas')

# %%
projected = geo.project(ds, area_def='HYR-LAEA-5', method='conservative')
projected.compute().ana.one_map(var='tas')

# %%
projected = geo.project(ds, area_def='HYR-LAEA-5', method='pyresample_nearest_neighbor')
projected.compute().ana.one_map(var='tas')

# %%
projected = geo.project(ds, area_def='HYR-LAEA-5', method='pyresample_bilinear')
projected.compute().ana.one_map(var='tas')

# %%
projected = geo.project(ds, area_def='HYR-LAEA-5', method='pyresample_idw', power_parameter=2)
projected.compute().ana.one_map(var='tas')

# %%
projected = geo.project(ds, area_def='HYR-LAEA-5', method='esmf_conservative')
projected.compute().ana.one_map(var='tas')

# %%
projected = geo.project(ds, area_def='HYR-LAEA-5', method='esmf_conservative_normed')
projected.compute().ana.one_map(var='tas')

# %%
projected = geo.project(ds, area_def='HYR-LAEA-5', method='esmf_patch')
projected.compute().ana.one_map(var='tas')

# %%
projected = geo.project(ds, area_def='HYR-LAEA-5', method='esmf_nearest_s2d')
projected.compute().ana.one_map(var='tas')

# %%
projected = geo.project(ds, area_def='HYR-LAEA-5', method='esmf_nearest_d2s')
projected.compute().ana.one_map(var='tas')

# %%
projected = geo.project(ds, area_def='HYR-LAEA-5', method='esmf_bilinear')
projected.compute().ana.one_map(var='tas')

# %%
projected = geo.project(ds, area_def='HYR-LAEA-5', method='pyresample_bilinear_swath_to_grid')
projected.compute().ana.one_map(var='tas')

# %%
projected = geo.project(ds, area_def='HYR-LAEA-5', method='pyresample_bilinear_swath_to_grid_legacy')
projected.compute().ana.one_map(var='tas')

# %%
projected = geo.project(ds, area_def='HYR-LAEA-5', method='pyresample_bilinear_swath_to_swath_legacy')
projected.compute().ana.one_map(var='tas')

# %%
projected = geo.project(ds, area_def='HYR-LAEA-5', method='pyresample_nearest_neighbor_legacy')
projected.compute().ana.one_map(var='tas')
